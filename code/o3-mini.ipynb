# %%
import pandas as pd
from openai import OpenAI
import time
import re

# %%
base_url = ""
api_key = ""
client = OpenAI(api_key=api_key, base_url=base_url)

# %% [markdown]
# #basic prompt

# %%
input_df = pd.read_csv('variant1.csv')
input_terms = input_df.iloc[10:, 2].tolist()
print(input_terms)
# Out:
# ['禾蟹', '长芝士', '桑心', '木友', '博友', '尼马', '耗子尾脂', '虾仁猪馨', '石乐志', '脑辅', '兵阔落', '四摘蒸鹅心', '舅伏你', '斑烛', '兰瘦', '相菇', '阔矣', '履装', '刹雕', '光腚肿菊', '夺笋', '吃早药丸', '虾米', '歪果人', '媒女', '耀店碧莲', '攻承狮', '布吉捣', '慷康', '开森', '脊美', '瑟擒', '雨女吾瓜', '迈银', '鸡你太每', '棒埠住了', '亚历山大', '有目有', '吵鸡', '媚纸', '鸡动', '括爱', '由菜花', '均男', '冲鸦', '泰裤腊', '乌鱼子', '肖死', '酒惊考验', '遵嘟假嘟', '针不戳', '介各', '乃们', '嘞各', '脚华', '米呼悠', '油猫病', '布响丸蜡', '九敏', '哈仁', '亩鸡', '咋肥肆', '戈们', '火前刘明', '伞冰', '尼萌', '撒币', '渴刑', '紫纱', '遂碎平安', '李姐腕岁', '矩个栗子', '我太南了', '和兰拔智齿', '鳖载着理发淀', '鸠载着礼发店', '举扮', '摄轻内容', '浮慕', '蕉律', '自抱字泣', '恼婆', '暑鼠', '蜀鼠', '出升', '很贵', '过沪', '二毕', '依托答便', '豹肖', '过粪', '究蝉', '国楠', '细嗦', '费雾', '纱了', '裹党', '玉玉政', '桌急', '游墨', '蓝棚友', '强裂', '秃燃', '好方', '拱出趣', '碎嚼', '鸡蔽你', '威距', '笔馨', '布毫', '捕药', '毫汀', '豪堪', '速随', '尼萌壕', '完辣', '籍士', '海规', '冷蛋', '帜杖', '范剑', '沿究牲', '蚝喜欢倪', '每眉', '香坛莲碍辣', '窝爱拟', '好事花生', '筷枣我丸', '享溅泥', '偶滴神', '翰纸', '牢资', '朦混过关', '感脚', '盆友', '彻硕', '基肚', '贷清', '果匠', '腐逐', '恢常', '蒸主', '滚粗', '草倪马', '毫赤', '盐豆怖盐', '戴嘤', '令人稚熄', '泥垢了', '莓拟不行', '晓崽汁', '打码', '蜡么', '赤蚀', '若智', '偶素酱姊滴', '蜡鸡', '瑰途', '冻离', '我宣你', '苦查子', '算了吧', '粗发', '可奈', '认碟', '淫家', '友内味了', '恰饭', '寄己', '进孝', '烦而晒', '皮燕子', '找驶', '温尤', '棚油', '杨尾', '侵耐的', '却食', '嵩子', '森器', '忧桑', '仙森', '糖顽了', '扒粑麻麻', '鲁煮', '大虾', '沃槽', '劳大', '痴史', '发粪途强', '布鸣真项', '释石真象', '恐怖粪址', '愣森', '羞设', '寿桑', '餐俱', '喜具', '斑猪', '主玉米', '竹页', '公脂', '砖夹', '帅锅', '北北', '朱脚', '灰墙', '雾划', '豆你丸', '苹神么', '算你狠', '穷吟', '担砂', '舌精病', '乳殿', '资词', '气馆炎', '试芥末日', '飞侮', '啤鼓', '高富帅', '彪子', '疆你军', '啡珠牛', '炫腹', '挠谈', '啥杯', '豆沙了', '葱白', '拉轰', '镁缕', '蛙去', '轻五肥羊', '情胜', '集冒', '碍姬', '点馨局', '新蚊帘啵', '知本家', '废柴', '烙铁', '夏崽', '海盾', '岭倒', '湿太', '大点画', '青斤', '水饺', '喝呵有名', '见谈', '诗人', '摇盐', '干色摸', '界果', '口年', '麻油', '亩代', '统子', '内个', '刘言板', '黄遥', '真人寿', '内牛满面', '野株', '单肾贵足', '宴南', '负翁', '寺滴', '漠迹', '守表', '粗线', '油柄', '贡眠', '骚年', '狐建', '酿紫', '药拟命', '咩厉', '泊魏', '值掌', '栽肿', '铸臂', '大叨', '蓝虑', '抢竭饭', '你材', '初沈', '鸟攻', '晕蔡', '墙淫', '掌姿势', '版猪', '吸份车', '表降紫', '别具一革', '泊课', '勃梗儿', '别无锁求', '鳖来吴恙', '奔寺', '惨库', '察具', '村天', '大骗子', '大卫', '蛋定', '碉保', '冻蓉', '肥猪流', '烦客体', '粉息饭', '愤青', '非蝗芜湖', '蜂和日历', '搁你肉', '盖世无双', '海代', '盒情和理', '壶合', '黄桑', '专盐', '猪你快乐', '昭高', '皂骗', '坐佳', '仄各', '供举', '吟洋人', '吟们', '晓姿', '挖卡卡', '老止', '佳欣', '统子们', '特么', '米国', '圣女', '刘弊', '腻害', '暖被儿奖', '男票', '兽不鸟', '偶面', '肉积', '跑牛', '迄死我乐', '琼兄极饿', '仁参', '拟缩', '沙笔', '软昧币', '原子诞', '侄乎', '找子', '意外趋饰']

# %%
input_terms = input_df.iloc[109:, 2].tolist()
print(input_terms)
# Out:
# ['果党', '玉玉症', '捉急', '油墨', '蓝朋友', '墙裂', '秃然', '好方', '拱出去', '碎觉', '鸡毕你', '微距', '笔芯', '布豪', '补药', '濠汀', '濠堪', '素随', '泥萌壕', '丸辣', '吉士', '海龟', '冷蛋', '制杖', '贩剑', '研究牲', '蚝喜欢泥', '美眉', '香坛莲爱辣', '窝爱你', '好事花生', '筷枣我丸', '响溅泥', '偶滴神', '汉纸', '劳资', '萌混过关', '赶脚', '盆友', '撤硕', '鸡肚', '带清', '果酱', '腐竹', '群猪', '灰常', '蒸煮', '滚粗', '草泥马', '豪赤', '盐豆不盐', '带嘤', '令人智熄', '泥垢了', '莓你不行', '小崽汁', '打马', '辣么', '非柱', '赤石', '若质', '偶素酱紫滴', '辣鸡', '归途', '骇死我了', '冻梨', '我宣你', '苦茶子', '蒜了吧', '粗发', '可耐', '认叠', '银家', '有内味了', '恰饭', '寄几', '辟谷', '进校', '烦而晒', '皮燕子', '找屎', '温油', '朋油', '杨伟', '亲耐的', '斐济', '雀食', '松子', '森气', '优桑', '先森', '糖丸了', '粑粑麻麻', '卤煮', '大虾', '卧槽', '牢大', '吃史', '发粪涂强', '布鸣真象', '噬石真象', '恐怖粪纸', '愣森', '羞射', '受桑', '餐具', '洗具', '班猪', '煮玉米', '竹叶', '公蜘', '砖家', '帅锅', '北北', '猪脚', '灰强', '雾化', '豆你玩', '苹什么', '蒜你狠', '穷银', '丹砂', '蛇精病', '乳垫', '资瓷', '气管炎', '是芥末日', '飞舞', '皮鼓', '糕富帅', '彪子', '姜你军', '非珠牛', '炫腹', '挠谈', '啥杯', '豆沙了', '葱白', '拉轰', '镁铝', '蛙趣', '轻舞肥羊', '情剩', '集贸', '爱姬', '点心局', '新蚊连啵', '知本家', '废柴', '烙铁', '下崽', '海囤', '领倒', '师太', '大点化', '青筋', '水饺', '喝喝有名', '贱谈', '湿人', '谣盐', '干色摸', '介果', '口年', '麻油', '母代', '筒子', '内个', '流言板', '黄姚', '真人兽', '内牛满面', '野猪', '单肾贵族', '燕南', '负翁', '四滴', '墨迹', '手表', '粗线', '油饼', '共眠', '骚年', '胡建', '酿紫', '药你命', '咩力', '泊位', '执掌', '栽种', '铸币', '大刀', '蓝绿', '抢节饭', '你才', '烧货', '初审', '鸟公', '晕菜', '强淫', '涨姿势', '板猪', '吸奋车', '表酱紫', '别具一革', '泊客', '博梗儿', '别无锁求', '鳖来无恙', '奔四', '惨酷', '茶具', '村天', '大片子', '大卫', '蛋腚', '碉堡', '冻容', '肥猪流', '烦客体', '粉稀饭', '粪青', '飞蝗芜湖', '蜂和日历', '鸽你肉', '钙世无双', '海待', '盒情盒理', '胡合', '黄桑', '专研', '猪你快乐', '招高', '皂片', '坐家', '仄个', '公举', '银洋人', '银们', '小姿', '挖卡卡', '老纸', '嘉欣', '筒子们', '特么', '米国', '剩女', '流弊', '腻害', '暖被儿奖', '男票', '受不鸟', '偶面', '肉鸡', '跑牛', '气死我乐', '穷兄极饿', '人参', '你缩', '煞笔', '软妹币', '原子蛋', '殖乎', '爪子', '意外趋势']

# %%
# prompt_basic = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会接收到一个中文谐音词作为输入内容，请准确将其还原为原本的词汇，然后只输出一个符合 {"原词": "XXX"} 格式的 JSON 数据，这里的 “XXX” 就是你所输入的谐音词所对应的原本词汇。

# /* 输入 */
# 当前的输入是：'''

# %%
# prompt_context = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的中文谐音词作为输入内容，请准确将其中的谐音词还原为原本的词汇，直接输出且只输出一个符合 {{"原词": "XXX"}} 格式的 JSON 数据，这里的 “XXX” 就是输入谐音词所对应的原本的中文词汇。输出中只能含有该json数据，而不能包含其他任何多余信息。


# /* 输入 */
# 句子输入：
# 谐音词：'''

# %%
# prompt_pinyin = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的拼音，以及句子中的谐音词和谐音词的拼音作为输入内容，请准确将其中的谐音词还原为原本的词汇，直接输出且只输出一个符合 {{"原词": "XXX"}} 格式的 JSON 数据，这里的 “XXX” 就是输入谐音词所对应的原本的中文词汇。输出中只能含有该json数据，而不能包含其他任何多余信息。

# /* 输入 */
# 句子输入：
# 句子输入的拼音：
# 谐音词：
# 谐音词的拼音：'''

# %%
# prompt_cot = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的谐音词作为输入内容，请首先给出思考推理的过程，然后准确地将句子的谐音词还原为原本的词汇，最后只输出样式为 {"推理过程": "XXX","原词": "XXX"} 的 JSON 数据，这里的第一个 "XXX" 是你推理的过程，第二个 "XXX" 就是你所输入的谐音词所对应的原本词汇。 输出中只能含有该json样式的数据，而不能包含其他任何多余信息。

# /* 输入 */
# 句子输入：
# 谐音词：'''

# %%
# prompt_mot = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的谐音词作为输入内容，请首先给出思考推理的过程，思考过程的样式仅参考我给出的示例，然后准确地将句子的谐音词还原为原本的词汇，最后只输出样式为 {"推理过程": "XXX","原词": "XXX"} 的 JSON 数据，这里的第一个 "XXX" 是你推理的过程，第二个 "XXX" 就是你所输入的谐音词所对应的原本词汇。 输出中只能含有该json样式的数据，而不能包含其他任何多余信息。

# /* 示例 */
# 句子输入：不要对我人参公鸡，否则我让管理员过来处理了。
# 谐音词:人参公鸡
# 输出为：{"推理过程":"'人参公鸡'的拼音是[[ren2],[shen1],[gong1],[ji1]]，原词应该为'人身攻击'，拼音是 [[ren2],[shen1],[gong1],[ji1]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中的'参'，'公'和'鸡'字属于遭到置换的字。他们分别经历将'身'替换为'参'，将'攻'替换为'公'，将'击'替换为'鸡'。这一现象仅改变了汉字写法，保持发音一致形成了谐音效果","原词"："人身攻击"}
# 句子输入：你肿么了？身体不舒服吗？
# 谐音词:肿么了
# 输出为：{{"推理过程":"'肿么了'的拼音[[zhong3],[me5],[le5]]，原词应该为'怎么了'，拼音为[[zen3],[me5],[le5]]。这是属于单纯的拼音拼写发生替换（发声位置发生变化）但是音调没有发生变化从而形成的谐音词现象。这个谐音词中的'肿'属于遭到置换的字。它的拼音拼写中的zh变成了z， IPA音标从[tʂ]变为[ts]，发音位置从卷舌擦音变为齿龈塞擦音，而且'怎'替换为'肿'。这一现象不仅改变了汉字写法而且改变了发音位置从而形成了谐音效果","原词":"怎么了"}
# 句子输入：这个综艺请的所谓专家根本是个叫兽！
# 谐音词：叫兽
# 输出为：{{"推理过程":"'叫兽'的拼音[[jiao4],[shou4]],原词应该为'教授',拼音为[[jiao4],[shou4]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中'叫'和'兽'字属于遭到替换的字。他们分别经历将"教"替换为'叫'，将"授"替换为"兽。这一现象仅改变了汉字写法，保持发音一致形成了谐音效果","原词"："教授"}}"

# /* 输入 */
# 句子输入：
# 谐音词：'''

# %%
# prompt_few_shot = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的中文谐音词作为输入内容，请准确将其中的谐音词还原为原本的词汇，直接输出且只输出一个符合 {{"原词": "XXX"}} 格式的 JSON 数据，这里的 “XXX” 就是输入谐音词所对应的原本的中文词汇。输出中只能含有该json数据，而不能包含其他任何多余信息。

# /* 示例 */
# （1）句子输入：不要对我人参公鸡，否则我让管理员过来处理了。
# 谐音词:人参公鸡
# 输出为：{{"原词": "人身攻击"}}
# （2）句子输入：你肿么了？身体不舒服吗？
# 谐音词:肿么了
# 输出为：{{"原词": "怎么了"}}
# （3）句子输入：这个综艺请的所谓专家根本是个叫兽！
# 谐音词:叫兽
# 输出为：{{"原词":"教授"}}

# /* 输入 */
# 句子输入：
# 谐音词：'''

# %%
from tqdm import tqdm

output_data = []

for term in tqdm(input_terms, desc="生成进度"):
    prompt = f'''\
/* 指令 */
你是一位专业的中文语言分析专家。你会接收到一个中文谐音词作为输入内容，请准确将其还原为原本的词汇，然后只输出一个符合 {{"原词": "XXX"}} 格式的 JSON 数据，这里的 “XXX” 就是你所输入的谐音词所对应的原本词汇。

/* 输入 */
当前的输入是：
{term}'''# we should replace the prompt from previous code blocks


    response = client.chat.completions.create(
        model="o3-mini",
        messages=[
            {"role": "system", "content": "你是一位专业的中文语言分析专家。"},
            {"role": "user", "content": prompt}
        ],
        temperature=0,
        stream=False
    )

    output_data.append({
        "word": term,
        "sentence": response.choices[0].message.content.strip()
    })

    time.sleep(1)
    print(f"已完成: {term} -> {response.choices[0].message.content.strip()}")

pd.DataFrame(output_data).to_csv('output.csv', index=False, encoding='utf-8-sig')
