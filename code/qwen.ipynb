# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import pandas as pd
input_df = pd.read_csv('/content/data_with_all_varient1.csv')
input_terms = input_df.iloc[:, 1].tolist()
input_varient1 = list(input_df['variant1'])
input_varient2 = list(input_df['variant2'])
input_varient3 = list(input_df['variant3'])
input_varient4 = list(input_df['variant4'])
input_vairent = input_varient1+input_varient2+input_varient3+input_varient4
input_terms_homo_pinyin = list(input_df['homophone_pinyin'])
input_sen_homo_pinyin = list(input_df['sen_pinyin'])
input_sen = list(input_df['sentence'])
print(input_terms)
# Out:
# ['神马', '杯具', '鸭梨', '围脖', '童鞋', '矮油', '菇凉', '酱紫', '稀饭', '驴友', '河蟹', '涨芝士', '桑心', '木有', '脖友', '尼玛', '耗子尾汁', '虾仁猪心', '石乐志', '脑斧', '冰阔落', '四斋蒸鹅心', '舅服你', '斑竹', '蓝瘦', '香菇', '阔以', '铝装', '沙雕', '光腚肿菊', '夺笋', '吃枣药丸', '虾米', '歪果仁', '霉女', '药店碧莲', '攻城狮', '布吉岛', '康康', '开森', '集美', '瑟琴', '雨女无瓜', '卖银', '鸡你太美', '蚌埠住了', '亚历山大', '有木有', '炒鸡', '妹纸', '鸡冻', '阔爱', '油菜花', '菌男', '冲鸭', '泰裤辣', '乌鱼子', '孝死', '酒精考验', '尊嘟假嘟', '针不戳', '介个', '乃们', '嘞个', '脚滑', '米忽悠', '油猫病', '布响丸辣', '九敏', '哈人', '母鸡', '咋肥四', '鸽们', '火钳刘明', '伞兵', '泥萌', '撒币', '可刑', '紫砂', '碎碎平安', '李姐万岁', '举个栗子', '我太南了', '荷兰拔智齿', '鳖载着理发店', '鸠载着理发店', '举办', '摄卿内容', '浮木', '蕉绿', '自抱自泣', '脑婆', '鼠鼠', '蜀黍', '出生', '很跪', '过沪', '二臂', '依托答辩', '豹笑', '过粪', '揪蝉', '国楠', '细嗦', '肺雾', '沙了', '果党', '玉玉症', '捉急', '油墨', '蓝朋友', '墙裂', '秃然', '好方', '拱出去', '碎觉', '鸡毕你', '微距', '笔芯', '布豪', '补药', '濠汀', '濠堪', '素随', '泥萌壕', '丸辣', '吉士', '海龟', '冷蛋', '制杖', '贩剑', '研究牲', '蚝喜欢泥', '美眉', '香坛莲爱辣', '窝爱你', '好事花生', '筷枣我丸', '响溅泥', '偶滴神', '汉纸', '劳资', '萌混过关', '赶脚', '盆友', '撤硕', '鸡肚', '带清', '果酱', '腐竹', '灰常', '蒸煮', '滚粗', '草泥马', '豪赤', '盐豆不盐', '带嘤', '令人智熄', '泥垢了', '莓你不行', '小崽汁', '打马', '辣么', '赤石', '若质', '偶素酱紫滴', '辣鸡', '归途', '冻梨', '我宣你', '苦茶子', '蒜了吧', '粗发', '可耐', '认叠', '银家', '有内味了', '恰饭', '寄几', '进校', '烦而晒', '皮燕子', '找屎', '温油', '朋油', '杨伟', '亲耐的', '雀食', '松子', '森气', '优桑', '先森', '糖丸了', '粑粑麻麻', '卤煮', '大虾', '卧槽', '牢大', '吃史', '发粪涂强', '布鸣真象', '噬石真象', '恐怖粪纸', '愣森', '羞射', '受桑', '餐具', '洗具', '班猪', '煮玉米', '竹叶', '公蜘', '砖家', '帅锅', '北北', '猪脚', '灰强', '雾化', '豆你玩', '苹什么', '蒜你狠', '穷银', '丹砂', '蛇精病', '乳垫', '资瓷', '气管炎', '是芥末日', '飞舞', '皮鼓', '糕富帅', '彪子', '姜你军', '非珠牛', '炫腹', '挠谈', '啥杯', '豆沙了', '葱白', '拉轰', '镁铝', '蛙趣', '轻舞肥羊', '情剩', '集贸', '爱姬', '点心局', '新蚊连啵', '知本家', '废柴', '烙铁', '下崽', '海囤', '领倒', '师太', '大点化', '青筋', '水饺', '喝喝有名', '贱谈', '湿人', '谣盐', '干色摸', '介果', '口年', '麻油', '母代', '筒子', '内个', '流言板', '黄姚', '真人兽', '内牛满面', '野猪', '单肾贵族', '燕南', '负翁', '四滴', '墨迹', '手表', '粗线', '油饼', '共眠', '骚年', '胡建', '酿紫', '药你命', '咩力', '泊位', '执掌', '栽种', '铸币', '大刀', '蓝绿', '抢节饭', '你才', '初审', '鸟公', '晕菜', '强淫', '涨姿势', '板猪', '吸奋车', '表酱紫', '别具一革', '泊客', '脖梗儿', '别无锁求', '鳖来无恙', '奔四', '惨酷', '茶具', '村天', '大片子', '大卫', '蛋腚', '碉堡', '冻容', '肥猪流', '烦客体', '粉稀饭', '粪青', '飞蝗芜湖', '蜂和日历', '鸽你肉', '钙世无双', '海待', '盒情盒理', '胡合', '黄桑', '专研', '猪你快乐', '招高', '皂片', '坐家', '仄个', '公举', '银洋人', '银们', '小姿', '挖卡卡', '老纸', '嘉欣', '筒子们', '特么', '米国', '圣女', '流弊', '腻害', '暖被儿奖', '男票', '受不鸟', '偶面', '肉鸡', '跑牛', '气死我乐', '穷兄极饿', '人参', '你缩', '煞笔', '软妹币', '原子蛋', '殖乎', '爪子', '意外趋势']

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from tqdm import tqdm
import torch

model_name = "Qwen/Qwen2.5-7B-Instruct"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]

# %%
# prompt_basic = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会接收到一个中文谐音词作为输入内容，请准确将其还原为原本的词汇，然后只输出一个符合 {"原词": "XXX"} 格式的 JSON 数据，这里的 “XXX” 就是你所输入的谐音词所对应的原本词汇。

# /* 输入 */
# 当前的输入是：'''

# %%
# prompt_context = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的中文谐音词作为输入内容，请准确将其中的谐音词还原为原本的词汇，直接输出且只输出一个符合 {{"原词": "XXX"}} 格式的 JSON 数据，这里的 “XXX” 就是输入谐音词所对应的原本的中文词汇。输出中只能含有该json数据，而不能包含其他任何多余信息。


# /* 输入 */
# 句子输入：
# 谐音词：'''

# %%
# prompt_pinyin = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的拼音，以及句子中的谐音词和谐音词的拼音作为输入内容，请准确将其中的谐音词还原为原本的词汇，直接输出且只输出一个符合 {{"原词": "XXX"}} 格式的 JSON 数据，这里的 “XXX” 就是输入谐音词所对应的原本的中文词汇。输出中只能含有该json数据，而不能包含其他任何多余信息。

# /* 输入 */
# 句子输入：
# 句子输入的拼音：
# 谐音词：
# 谐音词的拼音：'''

# %%
# prompt_cot = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的谐音词作为输入内容，请首先给出思考推理的过程，然后准确地将句子的谐音词还原为原本的词汇，最后只输出样式为 {"推理过程": "XXX","原词": "XXX"} 的 JSON 数据，这里的第一个 "XXX" 是你推理的过程，第二个 "XXX" 就是你所输入的谐音词所对应的原本词汇。 输出中只能含有该json样式的数据，而不能包含其他任何多余信息。

# /* 输入 */
# 句子输入：
# 谐音词：'''

# %%
# prompt_mot = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的谐音词作为输入内容，请首先给出思考推理的过程，思考过程的样式仅参考我给出的示例，然后准确地将句子的谐音词还原为原本的词汇，最后只输出样式为 {"推理过程": "XXX","原词": "XXX"} 的 JSON 数据，这里的第一个 "XXX" 是你推理的过程，第二个 "XXX" 就是你所输入的谐音词所对应的原本词汇。 输出中只能含有该json样式的数据，而不能包含其他任何多余信息。

# /* 示例 */
# 句子输入：不要对我人参公鸡，否则我让管理员过来处理了。
# 谐音词:人参公鸡
# 输出为：{"推理过程":"'人参公鸡'的拼音是[[ren2],[shen1],[gong1],[ji1]]，原词应该为'人身攻击'，拼音是 [[ren2],[shen1],[gong1],[ji1]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中的'参'，'公'和'鸡'字属于遭到置换的字。他们分别经历将'身'替换为'参'，将'攻'替换为'公'，将'击'替换为'鸡'。这一现象仅改变了汉字写法，保持发音一致形成了谐音效果","原词"："人身攻击"}
# 句子输入：你肿么了？身体不舒服吗？
# 谐音词:肿么了
# 输出为：{{"推理过程":"'肿么了'的拼音[[zhong3],[me5],[le5]]，原词应该为'怎么了'，拼音为[[zen3],[me5],[le5]]。这是属于单纯的拼音拼写发生替换（发声位置发生变化）但是音调没有发生变化从而形成的谐音词现象。这个谐音词中的'肿'属于遭到置换的字。它的拼音拼写中的zh变成了z， IPA音标从[tʂ]变为[ts]，发音位置从卷舌擦音变为齿龈塞擦音，而且'怎'替换为'肿'。这一现象不仅改变了汉字写法而且改变了发音位置从而形成了谐音效果","原词":"怎么了"}
# 句子输入：这个综艺请的所谓专家根本是个叫兽！
# 谐音词：叫兽
# 输出为：{{"推理过程":"'叫兽'的拼音[[jiao4],[shou4]],原词应该为'教授',拼音为[[jiao4],[shou4]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中'叫'和'兽'字属于遭到替换的字。他们分别经历将"教"替换为'叫'，将"授"替换为"兽。这一现象仅改变了汉字写法，保持发音一致形成了谐音效果","原词"："教授"}}"

# /* 输入 */
# 句子输入：
# 谐音词：'''

# %%
# prompt_few_shot = f'''/* 指令 */
# 你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的中文谐音词作为输入内容，请准确将其中的谐音词还原为原本的词汇，直接输出且只输出一个符合 {{"原词": "XXX"}} 格式的 JSON 数据，这里的 “XXX” 就是输入谐音词所对应的原本的中文词汇。输出中只能含有该json数据，而不能包含其他任何多余信息。

# /* 示例 */
# （1）句子输入：不要对我人参公鸡，否则我让管理员过来处理了。
# 谐音词:人参公鸡
# 输出为：{{"原词": "人身攻击"}}
# （2）句子输入：你肿么了？身体不舒服吗？
# 谐音词:肿么了
# 输出为：{{"原词": "怎么了"}}
# （3）句子输入：这个综艺请的所谓专家根本是个叫兽！
# 谐音词:叫兽
# 输出为：{{"原词":"教授"}}

# /* 输入 */
# 句子输入：
# 谐音词：'''

# %%
from tqdm import tqdm

list2 = []

for term, sen in tqdm(zip(input_terms,input_sen), desc="生成进度"):
    prompt = f'''\
/* 指令 */
你是一位专业的中文语言分析专家。你会收到含有一个谐音词的中文句子和该句子中的谐音词作为输入内容，请首先给出思考推理的过程，思考过程的样式仅参考我给出的示例，然后准确地将句子的谐音词还原为原本的词汇，最后只输出样式为 {{"推理过程": "XXX","原词": "XXX"}} 的 JSON 数据，这里的第一个 "XXX" 是你推理的过程，第二个 "XXX" 就是你所输入的谐音词所对应的原本词汇。 输出中只能含有该json样式的数据，而不能包含其他任何多余信息。

/* 示例 */
句子输入：不要对我人参公鸡，否则我让管理员过来处理了。
谐音词:人参公鸡
输出为：{{"推理过程":"'人参公鸡'的拼音是[[ren2],[shen1],[gong1],[ji1]]，原词应该为'人身攻击'，拼音是 [[ren2],[shen1],[gong1],[ji1]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中的'参','公'和'鸡'字属于遭到置换的字。他们分别经历将'身'替换为'参'，将'攻'替换为'公'，将'击'替换为'鸡'。这一现象仅改变了汉字写法，保持发音一致形成了谐音效果","原词"："人身攻击"}}
句子输入：你肿么了？身体不舒服吗？
谐音词:肿么了
输出为：{{"推理过程":"'肿么了'的拼音[[zhong3],[me5],[le5]]，原词应该为'怎么了'，拼音为[[zen3],[me5],[le5]]。这是属于单纯的拼音拼写发生替换（发声位置发生变化）但是音调没有发生变化从而形成的谐音词现象。这个谐音词中的'肿'属于遭到置换的字。它的拼音拼写中的zh变成了z， IPA音标从[tʂ]变为[ts]，发音位置从卷舌擦音变为齿龈塞擦音，而且'怎'替换为'肿'。这一现象不仅改变了汉字写法而且改变了发音位置从而形成了谐音效果","原词":"怎么了"}}
句子输入：这个综艺请的所谓专家根本是个叫兽！
谐音词：叫兽
输出为：{{"推理过程":"'叫兽'的拼音[[jiao4],[shou4]],原词应该为'教授',拼音为[[jiao4],[shou4]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中'叫'和'兽'字属于遭到替换的字。他们分别经历将"教"替换为'叫'，将"授"替换为"兽。这一现象仅改变了汉字写法，保持发音一致形成了谐音效果","原词"："教授"}}"


/* 输入 */
句子输入：{sen}
谐音词：{term}
'''# we should replace the prompt from previous code blocks


    messages=[
            {"role": "system", "content": "你是一位专业的中文语言分析专家。"},
            {"role": "user", "content": prompt}
        ]


    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )


    inputs = tokenizer(text, return_tensors="pt").to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=2048,
        do_sample=False,
        num_beams=1,
        repetition_penalty=1.2,
        pad_token_id=tokenizer.eos_token_id
    )

    response = tokenizer.decode(
        outputs[0][inputs.input_ids.size(1):],
        skip_special_tokens=True
    )
    list2.append(response)

print("生成结果示例:", list2[:10])
# Out:
# 生成进度: 365it [34:00,  5.59s/it]
# 生成结果示例: ['{"推理过程":"\'神马\'的拼音[[shen2],[ma2]],原词应该为\'什么\',拼音为[[shi2],[mo2]]。这是属于简单的声母和韵母互换但整体读音相似造成的谐音词现象。这个谐音词中的\'神\'与\'什\'、\'马\'与\'么\'都只是部分字符进行了替换，并且保留了原有的声调不变。这种情况下，虽然书写形式不同，但在口语表达上容易产生混淆，形成谐音效果","原词":"什么"}', '{"推理过程":"\'杯具\'的拼音[[bei1],[ju4]],原词应该为\'悲剧\',拼音为[[bi1],[ju4]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中\'杯\'和\'剧\'字属于遭到替换的字。它们分别经历了将\'杯\'替换成\'悲\'，将\'具\'替换成\'剧\'。这一现象仅仅改变的是汉字书写形式，并且保留了相同的读音，因此形成了一种谐音的效果。","原词":"悲剧"}', '{"推理过程":"\'鸭梨\'的拼音[[ya2],[li2]], 原词应该为\'压力\', 拼音为[[yi4],[lv2]]. 这是一种典型的声母与韵母互换导致的谐音现象, 发音位置发生了改变但整体音节结构相似. \'鸭\'的声母\'y\'替换了\'压\'的声母\'y\', 韵母\'a\'替换了\'力\'的\'i\'. 而\'梨\'的\'l\'则对应于\'力\'的\'l\', 且两者的韵母都是-i(在汉语拼音里表现为i或ü). 因此, 整体上虽然具体字符不同, 但在语音学意义上可以视为近似读音,"原词":"压力"}', '{"推理过程":"\'围脖\'的拼音[[wei2],[bo1]], 原词应该为\'微博\', 拼音为[[we1],[wobo1]]. 这是属于部分声母和韵母不同的谐音词现象，虽然整体读音相似但存在细微差异。这个谐音词中的\'围\'与\'微\'在声母上有区别，\'脖\'与\'博\'在韵母上有不同。尽管如此，它们仍然可以被误认为是同一个词语，形成了一种特殊的谐音关系。因此，通过对比两个词语的含义及发音特点来确定正确的原词","原词":"微博"}', '{"推理过程":"\'童鞋\'的拼音[[tong2],[xie1]],原词应该为\'同学\',拼音为[[tong2],[xue2]]。这是属于部分声母和韵母不同的异读造成的谐音词现象，虽然整体发音相似但存在细微差异。这个谐音词中\'tong\'的部分发音相同，但\'hua\'被替换成\'duo\'。具体来说，\'学\'与\'鞋\'在某些方言或口语环境中容易混淆，尤其是尾音的不同导致听感上的接近性。这种情况下，尽管不是完全相同的词语，但在特定语境下可以产生谐音的效果","原词":"同学"}', '{"推理过程":"\'矮油\'的拼音[[dai3],[you2]],原词应该为\'油腻\',拼音为[[nì2],[yóu2]]。这是属于部分声母和韵母都发生了改变的谐音词现象。这个谐音词中的\'矮\'属于遭到替换的字的一部分。它由鼻腔辅音[n]开头改为舌尖后不送气清摩擦音[d],同时[-ei]韵尾改为了[-iəu]。虽然整体读音相似但具体发音部位、方式及元音都有差异,因此形成了一种新的谐音形式。","原词":"油腻"}', '{"推理过程":"\'菇凉\'的拼音[[gu1],[leng2]],原词应该为\'姑娘\',拼音为[[guang1],[rang2]]。这是属于部分声母、韵母相同但整体发音不同的谐音词现象。这个谐音词中的\'菇\'与\'姑\'虽然在某些方言或口语中有相似之处，但在标准普通话下差异明显；\'凉\'则直接对应的是\'娘\'的一部分读音特征。这种情况下，通过调整声母和韵母可以形成谐音关系。因此，\'菇\'被替换成\'姑\'，\'凉\'保留了一部分发音特性，最终形成了\'姑娘\'这个词。","原词":"姑娘"}', '{"推理过程":"\'酱紫\'的拼音[[jiang4],[zi3]],原词应该为\'这样\'，拼音为[[ya4],[zhe4]]。这是属于部分声母、韵母及轻声音节的变化导致的谐音词现象。\'酱\'与\'这\'在声母上不同，前者是边音[j],后者是舌尖后不送气清塞擦音[zh]; \'紫\'与\'样\'在韵母上有差异,前者是齐口呼[i],"样"属合口呼[uang]; 且\'紫\'为去声,[3],而\'样\'为阳平,[4]. 这种情况表明虽然整体读音相似但存在细微差别，形成了一定程度上的谐音关系。因此,\'酱紫\'是对\'这样\'的一种口语化或非正式表达方式","原词":"这样"}', '{"推理过程":"\'稀饭\'的拼音[[xi1],[fuan2]],原词应该为\'喜欢吃\',拼音为[[xi1],[hui4],[chi1],[pou2]]。这是属于部分声母、韵母及轻声音节被替代形成谐音的现象。在这个谐音词中,\'稀\'与\'hui\'的部分声母相同, \'饭\'与\'吃苹果\'在语境下通过语气表达出相似的意思。虽然整体上不是直接的文字替换而是语音上的近似，但这种形式仍然可以归类于谐音的一种表现方式。因此，\'稀饭\'在这里实际上是指\'喜欢吃\'。","原词":"喜欢吃"}', '{"推理过程":"\'驴友\'的拼音[[lu2],[you3]]，原词应该为\'旅游\'，拼音为[[lv2],[you3]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中的\'驴\'和\'友\'字属于遭到替换的字。它们分别经历了将\'旅\'替换为\'驴\'，将\'游\'替换为\'友\'。这一现象仅改变了汉字写法，保持发音一致形成了谐音效果","原词"："旅游"}']

# %%
print(list2)
# Out:
# ['{"推理过程":"\'神马\'的拼音[[shen2],[ma2]],原词应该为\'什么\',拼音为[[shi2],[mo2]]。这是属于简单的声母和韵母互换但整体读音相似造成的谐音词现象。这个谐音词中的\'神\'与\'什\'、\'马\'与\'么\'都只是部分字符进行了替换，并且保留了原有的声调不变。这种情况下，虽然书写形式不同，但在口语表达上容易产生混淆，形成谐音效果","原词":"什么"}', '{"推理过程":"\'杯具\'的拼音[[bei1],[ju4]],原词应该为\'悲剧\',拼音为[[bi1],[ju4]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中\'杯\'和\'剧\'字属于遭到替换的字。它们分别经历了将\'杯\'替换成\'悲\'，将\'具\'替换成\'剧\'。这一现象仅仅改变的是汉字书写形式，并且保留了相同的读音，因此形成了一种谐音的效果。","原词":"悲剧"}', '{"推理过程":"\'鸭梨\'的拼音[[ya2],[li2]], 原词应该为\'压力\', 拼音为[[yi4],[lv2]]. 这是一种典型的声母与韵母互换导致的谐音现象, 发音位置发生了改变但整体音节结构相似. \'鸭\'的声母\'y\'替换了\'压\'的声母\'y\', 韵母\'a\'替换了\'力\'的\'i\'. 而\'梨\'的\'l\'则对应于\'力\'的\'l\', 且两者的韵母都是-i(在汉语拼音里表现为i或ü). 因此, 整体上虽然具体字符不同, 但在语音学意义上可以视为近似读音,"原词":"压力"}', '{"推理过程":"\'围脖\'的拼音[[wei2],[bo1]], 原词应该为\'微博\', 拼音为[[we1],[wobo1]]. 这是属于部分声母和韵母不同的谐音词现象，虽然整体读音相似但存在细微差异。这个谐音词中的\'围\'与\'微\'在声母上有区别，\'脖\'与\'博\'在韵母上有不同。尽管如此，它们仍然可以被误认为是同一个词语，形成了一种特殊的谐音关系。因此，通过对比两个词语的含义及发音特点来确定正确的原词","原词":"微博"}', '{"推理过程":"\'童鞋\'的拼音[[tong2],[xie1]],原词应该为\'同学\',拼音为[[tong2],[xue2]]。这是属于部分声母和韵母不同的异读造成的谐音词现象，虽然整体发音相似但存在细微差异。这个谐音词中\'tong\'的部分发音相同，但\'hua\'被替换成\'duo\'。具体来说，\'学\'与\'鞋\'在某些方言或口语环境中容易混淆，尤其是尾音的不同导致听感上的接近性。这种情况下，尽管不是完全相同的词语，但在特定语境下可以产生谐音的效果","原词":"同学"}', '{"推理过程":"\'矮油\'的拼音[[dai3],[you2]],原词应该为\'油腻\',拼音为[[nì2],[yóu2]]。这是属于部分声母和韵母都发生了改变的谐音词现象。这个谐音词中的\'矮\'属于遭到替换的字的一部分。它由鼻腔辅音[n]开头改为舌尖后不送气清摩擦音[d],同时[-ei]韵尾改为了[-iəu]。虽然整体读音相似但具体发音部位、方式及元音都有差异,因此形成了一种新的谐音形式。","原词":"油腻"}', '{"推理过程":"\'菇凉\'的拼音[[gu1],[leng2]],原词应该为\'姑娘\',拼音为[[guang1],[rang2]]。这是属于部分声母、韵母相同但整体发音不同的谐音词现象。这个谐音词中的\'菇\'与\'姑\'虽然在某些方言或口语中有相似之处，但在标准普通话下差异明显；\'凉\'则直接对应的是\'娘\'的一部分读音特征。这种情况下，通过调整声母和韵母可以形成谐音关系。因此，\'菇\'被替换成\'姑\'，\'凉\'保留了一部分发音特性，最终形成了\'姑娘\'这个词。","原词":"姑娘"}', '{"推理过程":"\'酱紫\'的拼音[[jiang4],[zi3]],原词应该为\'这样\'，拼音为[[ya4],[zhe4]]。这是属于部分声母、韵母及轻声音节的变化导致的谐音词现象。\'酱\'与\'这\'在声母上不同，前者是边音[j],后者是舌尖后不送气清塞擦音[zh]; \'紫\'与\'样\'在韵母上有差异,前者是齐口呼[i],"样"属合口呼[uang]; 且\'紫\'为去声,[3],而\'样\'为阳平,[4]. 这种情况表明虽然整体读音相似但存在细微差别，形成了一定程度上的谐音关系。因此,\'酱紫\'是对\'这样\'的一种口语化或非正式表达方式","原词":"这样"}', '{"推理过程":"\'稀饭\'的拼音[[xi1],[fuan2]],原词应该为\'喜欢吃\',拼音为[[xi1],[hui4],[chi1],[pou2]]。这是属于部分声母、韵母及轻声音节被替代形成谐音的现象。在这个谐音词中,\'稀\'与\'hui\'的部分声母相同, \'饭\'与\'吃苹果\'在语境下通过语气表达出相似的意思。虽然整体上不是直接的文字替换而是语音上的近似，但这种形式仍然可以归类于谐音的一种表现方式。因此，\'稀饭\'在这里实际上是指\'喜欢吃\'。","原词":"喜欢吃"}', '{"推理过程":"\'驴友\'的拼音[[lu2],[you3]]，原词应该为\'旅游\'，拼音为[[lv2],[you3]]。这是属于完全的同音字置换形成的谐音词现象，拼音拼写（发声位置）以及音调没有发生任何变化。这个谐音词中的\'驴\'和\'友\'字属于遭到替换的字。它们分别经历了将\'旅\'替换为\'驴\'，将\'游\'替换为\'友\'。这一现象仅改变了汉字写法，保持发音一致形成了谐音效果","原词"："旅游"}', '{"推理过程":"\'河蟹\'的拼音[[he2],[xue1]],原词应该为\'和谐\',拼音为[[he2],[hexie2]]或直接简化为[[he2],[xie2]]。这是属于部分音节相同但整体词语不同的谐音词现象，其中\'河\'与\'和\'相似且都读作第二声\'hé\'；\'蟹\'则对应于\'谐\'，后者在某些语境下也读作第一声\'hé\'或者第四声\'xié\'。这种情况下，虽然两个词的部分音节相同，但由于整个词语的意义完全不同，并非简单的同音字置换而是通过近似音形成的一种特殊的谐音关系。因此，这里可以认为\'河蟹\'是对\'和谐\'的一个幽默化、贬义化的替代表达方式","原词"："和谐"}', '{"推理过程":"\'涨芝士\'的拼音[[zhang3],[chi2],[zi4]],原词应该为\'增长\'",拼音为[[zhang3],[zheng1]]. 这是一种部分声母、韵母相同但整体发音不同的谐音现象。在这个例子中，“涨”与“增”的区别在于声母的不同。“涨”的声母是翘舌音 “zh”，而“增”的声母是平舌音 “z”。同时，“芝”在两个词语里都读作二声，“士”则对应的是“星”。因此可以推断出‘涨’被误认为或故意替换成听起来相似但实际上意义不同的 ‘增’。这种情况下虽然存在一定的语音相近性，但在实际语境下容易造成理解上的混淆,"原词"："增长"}', '{"推理过程":"\'桑心\'的拼音[[sang1],[xin1]], 原词应该为\'伤心\'，拼音为[[shuang1],[xin1]]。这是属于部分声母不同的谐音词现象，虽然两个词语在韵母上相同或相近但声母不同导致读音相似。具体来说,\'桑\'的拼音[sɑŋ]与\'伤\'的[pʃwɛ̃]有差异, 但在口语交流中容易被误听成同一个词。这种情况下，\'桑\'替代了\'伤\'的位置，并且保留了相同的韵母\'i\'及大致相当的音高模式[iŋ]。因此，在语音层面两者较为接近，形成了一种特殊的谐音关系。","原词":"伤心"}', '{"推理过程":"\\"木有\\"的拼音是[[\'mu4\'], [\'you3\']]，原词应该为\\"没有\\"，拼音也是[[\'mu4\'], [\'you3\']]。这是一种典型的简化词语的现象，并非严格意义上的谐音词，但按照题目要求进行解释的话，可以认为是通过改变书写形式来达到表达相同意思的效果。在这个例子中，\'木\'与\'没\'在视觉上进行了替代，虽然它们的读音不同，但在口语交流中通常会被理解成同一个意义。不过根据题目的定义，这里主要关注的是文字上的差异而非语音上的差异。因此，我们可以说这种转换主要是基于形似而不是声似来进行的文字游戏或幽默手法。","原词":"没有"}', '{"推理过程":"\'脖友\'的拼音[[bo1],[you4]], 原词应该为\'博主\', 拼音为[[bo1],[zhuo2]]. 这是属于部分声母和韵母不同的谐音词现象, 发音位置发生了改变但整体音节结构相似且音调相同. \'脖\'与\'博\'在声母上不同,\'友\'与\'主\'在韵母上有差异. 通过观察发现\'脖友\'是对\'博主\'的一种幽默或戏谑性的替代表达方式, 更加口语化、形象生动.", "原词":"博主"}', '{"推理过程":"\'尼玛\'的拼音[[ni2],[ma1]],原词应该为\'尼姑妈\'",拼音为[[ni2],[mu1]]。这是属于部分声母和韵母替换但整体发音相似造成的谐音词现象。“尼”与“尼”相同，“玛”的m替换成更接近的m, 且a发成u近似音。虽然有细微差异，但在口语交流中容易被误听为‘尼玛’。这个谐音词中的\'ma\'的部分发生了改变，由\'a\'改为\'u\'，同时保留了前缀\'n\'不变。这种情况下，尽管不是完全相同的读音，但由于语 ...

# %%
pd.DataFrame(list2).to_csv('output_qwen_mot.csv', index=False, encoding='utf-8-sig')
